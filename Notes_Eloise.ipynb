# %% [markdown]
# ## Import pandas et numpy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
print('libs loaded')
# Out:
# libs loaded

# %% [markdown]
# ## Faire le dictionnaire des notes

# %%
Note_Eloise = {
    '1er trimestre' : [16.1,14.5,13.29,None ,10.5,17.27,15.68,16.45,15.75,15.46,16.5,17.65,18.4],
    '2ème trimestre' : [16.21,15.95,14.25,17,12,17.17,14.16,17.36,17.73,16.78,16.5,15.2,19.2],
    '3ème trimestre' : [18,None,11,None,None,20,13,15.6,None,None,None,None,None]
}

# %% [markdown]
# - Visualiser le dictionnaire

# %%
Note_Eloise
# Out:
# {'1er trimestre': [16.1,
#   14.5,
#   13.29,
#   None,
#   10.5,
#   17.27,
#   15.68,
#   16.45,
#   15.75,
#   15.46,
#   16.5,
#   17.65,
#   18.4],
#  '2ème trimestre': [16.21,
#   15.95,
#   14.25,
#   17,
#   12,
#   17.17,
#   14.16,
#   17.36,
#   17.73,
#   16.78,
#   16.5,
#   15.2,
#   19.2],
#  '3ème trimestre': [18,
#   None,
#   11,
#   None,
#   None,
#   20,
#   13,
#   15.6,
#   None,
#   None,
#   None,
#   None,
#   None]}

# %% [markdown]
# ## Faire un DataFrame du dictionnaire et le visualiser

# %%
df_elo = pd.DataFrame(Note_Eloise); df_elo
# Out:
#     1er trimestre  2ème trimestre  3ème trimestre
# 0           16.10           16.21            18.0
# 1           14.50           15.95             NaN
# 2           13.29           14.25            11.0
# 3             NaN           17.00             NaN
# 4           10.50           12.00             NaN
# 5           17.27           17.17            20.0
# 6           15.68           14.16            13.0
# 7           16.45           17.36            15.6
# 8           15.75           17.73             NaN
# 9           15.46           16.78             NaN
# 10          16.50           16.50             NaN
# 11          17.65           15.20             NaN
# 12          18.40           19.20             NaN

# %% [markdown]
# - Visualiser les informations sur le Dataframe

# %%
df_elo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   1er trimestre   12 non-null     float64
#  1   2ème trimestre  13 non-null     float64
#  2   3ème trimestre  5 non-null      float64
# dtypes: float64(3)
# memory usage: 440.0 bytes

# %% [markdown]
# - Visualiser les statistiques du Dataframe

# %%
df_elo.describe()
# Out:
#        1er trimestre  2ème trimestre  3ème trimestre
# count      12.000000       13.000000         5.00000
# mean       15.629167       16.116154        15.52000
# std         2.115061        1.854479         3.64033
# min        10.500000       12.000000        11.00000
# 25%        15.220000       15.200000        13.00000
# 50%        15.925000       16.500000        15.60000
# 75%        16.692500       17.170000        18.00000
# max        18.400000       19.200000        20.00000

# %% [markdown]
# ## Faire un indexes avec les matières faitent par Eloïse

# %%
matiere =['FRANCAIS','HIST.GEO.EDUC.CIVIQ','ANGLAIS LV1','CAMBRIDGE','ALLEMAND LV2', 'LCA LATIN', 'MATHEMATIQUE','SC.PHYSIQ.ET CHIMIQ.','SCIENCES VIE TERRE','TECHNOLOGIE','ED.PHYSIQUE & SPORT.','EDUCATION MUSICALE','ARTS PLASTIQUES']
df_elo = pd.DataFrame(Note_Eloise, index=matiere); df_elo
##df_elo = pd.DataFrame(Note_Eloise, index=['FRANCAIS','HIST.GEO.EDUC.CIVIQ','ANGLAIS LV1','CAMBRIDGE','ALLEMAND LV2', 'LCA LATIN', 'MATHEMATIQUE','SC.PHYSIQ.ET CHIMIQ.','SCIENCES VIE TERRE','TECHNOLOGIE','ED.PHYSIQUE & SPORT.','EDUCATION MUSICALE','ARTS PLASTIQUES']); df_elo
# Out:
#                       1er trimestre  2ème trimestre  3ème trimestre
# FRANCAIS                      16.10           16.21            18.0
# HIST.GEO.EDUC.CIVIQ           14.50           15.95             NaN
# ANGLAIS LV1                   13.29           14.25            11.0
# CAMBRIDGE                       NaN           17.00             NaN
# ALLEMAND LV2                  10.50           12.00             NaN
# LCA LATIN                     17.27           17.17            20.0
# MATHEMATIQUE                  15.68           14.16            13.0
# SC.PHYSIQ.ET CHIMIQ.          16.45           17.36            15.6
# SCIENCES VIE TERRE            15.75           17.73             NaN
# TECHNOLOGIE                   15.46           16.78             NaN
# ED.PHYSIQUE & SPORT.          16.50           16.50             NaN
# EDUCATION MUSICALE            17.65           15.20             NaN
# ARTS PLASTIQUES               18.40           19.20             NaN

# %% [markdown]
# ## Changer une valeur dans le tableau de moyen avec iat :
# * df_elo.iat[1,2] : Afecte la valeur 16 à la ligne 2 et la colonne 3 pour la ligne 'HIST.GEO.EDUC.CIVIQ' du troisième trimestre

# %%
df_elo.iat[1,2] = 16.0

# %%
df_elo.iat[0,2]  = 18.0  # FRANCAIS
df_elo.iat[1,2]  = 13.5  # HIST.GEO.EDUC.CIVIQ
df_elo.iat[2,2]  = 15.17 # ANGLAIS LV1
df_elo.iat[3,2]  = None  # CAMBRIDGE
df_elo.iat[4,2]  = None  # ALLEMAND LV2
df_elo.iat[5,2]  = 20    # LCA LATIN
df_elo.iat[6,2]  = 15.17 # MATHEMATIQUE
df_elo.iat[7,2]  = 16    # SC.PHYSIQ.ET CHIMIQ.
df_elo.iat[8,2]  = 16.7  # SCIENCES VIE TERRE
df_elo.iat[9,2]  = None  # TneHNOLOGIE
df_elo.iat[10,2] = None  # ED.PHYSIQUE & SPORT.
df_elo.iat[11,2] = None  # EDUCATION MUSICALE
df_elo.iat[12,2] = None  # ARTS PLASTIQUES

# %%
df_elo
# Out:
#                       1er trimestre  2ème trimestre  3ème trimestre
# FRANCAIS                      16.10           16.21           18.00
# HIST.GEO.EDUC.CIVIQ           14.50           15.95           13.50
# ANGLAIS LV1                   13.29           14.25           15.17
# CAMBRIDGE                       NaN           17.00             NaN
# ALLEMAND LV2                  10.50           12.00             NaN
# LCA LATIN                     17.27           17.17           20.00
# MATHEMATIQUE                  15.68           14.16           15.17
# SC.PHYSIQ.ET CHIMIQ.          16.45           17.36           16.00
# SCIENCES VIE TERRE            15.75           17.73           16.70
# TECHNOLOGIE                   15.46           16.78             NaN
# ED.PHYSIQUE & SPORT.          16.50           16.50             NaN
# EDUCATION MUSICALE            17.65           15.20             NaN
# ARTS PLASTIQUES               18.40           19.20             NaN

# %% [markdown]
# ## Calculer la moyen par trimestre

# %%
moyen = df_elo.mean( skipna = True )
Colonnes = ['Moyen trimeste']
df_elo_moyen = pd.DataFrame(moyen, columns = Colonnes); df_elo_moyen
# Out:
#                 Moyen trimeste
# 1er trimestre        15.629167
# 2ème trimestre       16.116154
# 3ème trimestre       16.362857

# %%
df_elo_moyen.loc['3ème trimestre', ]
# Out:
# Moyen trimeste    16.362857
# Name: 3ème trimestre, dtype: float64

# %%
df_elo_moyen.iloc[2:3]
# Out:
#                 Moyen trimeste
# 3ème trimestre       16.362857

# %% [markdown]
# ## Calculer la diférence des moyens entre le 2ème trimestre et 1er trimestre

# %%
df_elo['2ème trimestre'].mean( skipna = True )-df_elo['1er trimestre'].mean( skipna = True )
# Out:
# 0.4869871794871745

# %% [markdown]
# ## Calcul de la valeur médiane par trimestre

# %%
df_elo.median( skipna = True )
# Out:
# 1er trimestre     15.925
# 2ème trimestre    16.500
# 3ème trimestre    16.000
# dtype: float64

# %%
(15+(18*.25)+(18.5*.5)+(16*.25)+(18*.5))/2.5
# Out:
# 16.7

# %% [markdown]
# ## Graphique des notes et des matières

# %%
#plt.style.use('Solarize_Light2')
#plt.style.use('classic')
plt.style.use('grayscale')
plt.figure(figsize=(16,6))
plt.plot(matiere,df_elo['1er trimestre'], c = 'green', label= u"1er trimestre") 
plt.plot(matiere,df_elo['2ème trimestre'], c = 'red', label= u"2ème trimestre") 
plt.plot(matiere,df_elo['3ème trimestre'], c = 'blue', label= u"3ème trimestre") 
#plt.scatter(matiere,df_elo['1er trimestre'], c = 'green')
#plt.scatter(matiere,df_elo['2ème trimestre'], c = 'red')
#plt.scatter(matiere,df_elo['3ème trimestre'], c = 'blue')
plt.xlabel('Matières') # => libellé axe x
plt.ylabel('Notes sur 20') # => libellé axe y
plt.title(u'Un graphique avec les courbes des notes Eloïse de 4A')  # => titre du graphique
plt.xticks(rotation=45)
plt.grid(True)
plt.legend();

# %%
df_elo.dropna(subset = ['3ème trimestre'])
# Out:
#                       1er trimestre  2ème trimestre  3ème trimestre
# FRANCAIS                      16.10           16.21           18.00
# HIST.GEO.EDUC.CIVIQ           14.50           15.95           13.50
# ANGLAIS LV1                   13.29           14.25           15.17
# LCA LATIN                     17.27           17.17           20.00
# MATHEMATIQUE                  15.68           14.16           15.17
# SC.PHYSIQ.ET CHIMIQ.          16.45           17.36           16.00
# SCIENCES VIE TERRE            15.75           17.73           16.70

# %%
print("Matplotlib offre {} styles de graphiques".format(len(plt.style.available)))
# Out:
# Matplotlib offre 28 styles de graphiques

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(0,5,50)
y=np.sin(2 * np.pi * x)

plt.scatter(x,y,color='r',zorder=2)
plt.plot(x,y,color='b',zorder=1)

plt.title("Connected Scatterplot points with line")
plt.xlabel("x")
plt.ylabel("sinx")

plt.show()

# %%
data = np.random.randn(10,7)

# %%
data.ravel()[np.random.choice(data.size, 5, replace=False)] = np.nan

# %%
data
# Out:
# array([[ 0.21797619, -0.04468546, -0.73380036,  1.08184232, -0.09709407,
#          0.1562853 , -0.38969124],
#        [-1.16907312, -0.18480811,         nan,         nan, -0.41163711,
#         -0.55734   ,  0.25594389],
#        [ 0.96117368,  1.23157564,  1.05927176, -1.29882773, -0.21112079,
#         -0.94188689,  1.79910331],
#        [-0.67436237, -0.95906687,  0.48801701,  0.55086222, -0.76458205,
#          0.31744038, -0.20815715],
#        [        nan,  0.69233466, -1.86459193, -1.0701773 ,  2.00308752,
#         -1.36519118, -0.3230915 ],
#        [-1.80792568,  0.56946927,  0.83075921, -1.28118206,  1.61757768,
#          0.62696039, -1.29873907],
#        [-1.17951531, -0.64977293,  1.23837542,         nan,  1.29100223,
#          2.10327256,  0.96176486],
#        [-1.52957851, -1.24510558,  0.57835635, -0.68440526,  0.26507126,
#         -0.37733387, -0.4672479 ],
#        [ 0.37847073,  0.86814199,  0.37562386,  0.04496899, -0.06782828,
# ...

# %%
df = pd.DataFrame(data=data)

# %%
index_with_nan = df.index[df.isnull().any(axis=1)]

# %%
index_with_nan
# Out:
# Int64Index([1, 4, 6, 9], dtype='int64')

# %%
df_ligne_drop= df.drop(index_with_nan,0, inplace=True)
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#           0         1         2         3         4         5         6
# 0  0.217976 -0.044685 -0.733800  1.081842 -0.097094  0.156285 -0.389691
# 2  0.961174  1.231576  1.059272 -1.298828 -0.211121 -0.941887  1.799103
# 3 -0.674362 -0.959067  0.488017  0.550862 -0.764582  0.317440 -0.208157
# 5 -1.807926  0.569469  0.830759 -1.281182  1.617578  0.626960 -1.298739
# 7 -1.529579 -1.245106  0.578356 -0.684405  0.265071 -0.377334 -0.467248
# 8  0.378471  0.868142  0.375624  0.044969 -0.067828  0.355641 -1.727362
